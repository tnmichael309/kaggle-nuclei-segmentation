# %% [markdown]
# # Import dependencies

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.5/dist-packages
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.5/dist-packages (from keras)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.5/dist-packages (from keras)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.5/dist-packages (from keras)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.5/dist-packages (from keras)

# %%
# !pip install cython
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.5/dist-packages

# %%
import sys
sys.path.append('Mask_RCNN')

# %%
import os
import sys
import random
import math
import re
import time

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
#sess = tf.Session(config=config)

from keras import backend as K
K.set_session(sess)

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import csv
import imageio
import skimage
from config import Config
from skimage.morphology import label
from skimage.feature import canny
from skimage import exposure
from keras.callbacks import Callback
from skimage.morphology import binary_closing, binary_opening, disk, binary_dilation
from scipy.ndimage.morphology import binary_fill_holes
from sklearn.externals import joblib
from skimage.transform import PiecewiseAffineTransform, warp
from skimage.morphology import watershed
from skimage.filters import sobel
from preparation import vgg_feature_extractor
from random import *

import gc; gc.enable()
import utils
import model as modellib
import visualize
from model import log
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Let's download the mask_rcnn trained on COCO dataset to initialize the model.

# %%
pd.options.display.max_rows=100

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %% [markdown]
# We will now define the monitor that will help keep track on the training process.
# With this you will be able to see your charts in the `charts` tab

# %% [markdown]
# Now we will load the metadata and divide them in train and valid splits

# %%
TRAIN_PATH = '../stage1_train'
TEST_PATH = '../stage1_test'
META_DATA_PATH = '../stage1_metadata.csv'
BG_DATA_PATH = '../stage1_backgroud_foreground_classes.csv'

# %%
if not os.path.exists(META_DATA_PATH):
    print('Generating metadata.csv')
    
    stage1_metadata = pd.DataFrame()
    
    train_image_ids = os.listdir(TRAIN_PATH) # ImageId
    train_is_train = [1] * len(train_image_ids)
    
    train_file_path = []
    for p in train_image_ids:
        if p[:4] == 'TCGA':
            train_file_path.append(TRAIN_PATH + '/' + p + '/images/' + p + '.tif')
        else:
            train_file_path.append(TRAIN_PATH + '/' + p + '/images/' + p + '.png')
    
    test_image_ids = os.listdir(TEST_PATH) # ImageId
    test_is_train = [0] * len(test_image_ids)
    test_file_path = [TEST_PATH + '/' + p + '/images/' + p + '.png' for p in test_image_ids]
    
    stage1_metadata['ImageId'] = np.concatenate([train_image_ids, test_image_ids], axis=0)
    stage1_metadata['is_train'] = np.concatenate([train_is_train, test_is_train], axis=0)
    stage1_metadata['file_path_image'] = np.concatenate([train_file_path, test_file_path], axis=0)
    
    ve = vgg_feature_extractor(n_clusters=10)
    train_vgg_features_clusters = ve.get_vgg_clusters(stage1_metadata[stage1_metadata.is_train == 1].reset_index(drop=True), is_train=True)
    test_vgg_features_clusters =ve.get_vgg_clusters(stage1_metadata[stage1_metadata.is_train == 0].reset_index(drop=True), is_train=False)
    
    stage1_metadata['vgg_features_clusters'] = np.concatenate([train_vgg_features_clusters, test_vgg_features_clusters], axis=0)
    
    stage1_metadata.to_csv(META_DATA_PATH, index=False)
    meta = stage1_metadata
    
    del vgg_feature_extractor; gc.collect()
else:
    meta = pd.read_csv(META_DATA_PATH)
    

meta.head(100)
# Out:
#                                               ImageId  is_train  \
# 745                        TCGA-AY-A8YK-01A-01-TS1.tif     purple     purple
# 746                        TCGA-B0-5698-01Z-00-DX1.tif     purple     purple
# 747                        TCGA-B0-5710-01Z-00-DX1.tif     purple     purple
# 748                        TCGA-B0-5711-01Z-00-DX1.tif     purple     purple
# 749                        TCGA-CH-5767-01Z-00-DX1.tif     purple     purple
# 750                        TCGA-DK-A2I6-01A-01-TS1.tif     purple     purple
# 751                        TCGA-E2-A14V-01Z-00-DX1.tif     purple     purple
# 752                        TCGA-E2-A1B5-01Z-00-DX1.tif     purple     purple
# 753                        TCGA-G2-A2EK-01A-02-TSB.tif     purple     purple
# 754                        TCGA-G9-6336-01Z-00-DX1.tif     purple     purple
# 755                        TCGA-G9-6348-01Z-00-DX1.tif     purple     purple
# 756                        TCGA-G9-6356-01Z-00-DX1.tif     purple     purple
# 757                        TCGA-G9-6362-01Z-00-DX1.tif     purple     purple
# 758                        TCGA-G9-6363-01Z-00-DX1.tif     purple     purple
# 759                        TCGA-HE-7128-01Z-00-DX1.tif     purple     purple
# 760                        TCGA-HE-7129-01Z-00-DX1.tif     purple     purple
# 761                        TCGA-HE-7130-01Z-00-DX1.tif     purple     purple
# 762                        TCGA-KB-A93J-01A-01-TS1.tif     purple     purple
# 763                        TCGA-NH-A8F7-01A-01-TS1.tif     purple     purple
# 764                        TCGA-RD-A8N9-01A-01-TS1.tif     purple     purple

# %%
back_ground_df['ImageId'] = [fn.replace('.png', '') if fn[-4:] == '.png' else fn.replace('.tif', '') for fn in back_ground_df.filename]
print('Image ID in background data counts:\n', meta.ImageId.isin(back_ground_df.ImageId).value_counts())
# Out:
# Image ID in background data counts:
#  True    759
# Name: ImageId, dtype: int64

# %%
back_ground_df.background.value_counts()
# Out:
# black     599
# purple    101
# white      57
# yellow      8
# Name: background, dtype: int64

# %%
back_ground_df.foreground.value_counts()
# Out:
# white     599
# purple    150
# black      16
# Name: foreground, dtype: int64

# %%
back_ground_df['composed_bf_ground'] = back_ground_df.background.astype(str) + '_' + back_ground_df.foreground.astype(str)
back_ground_df.composed_bf_ground.value_counts()
# Out:
# black_white      599
# purple_purple    101
# white_purple      41
# white_black       16
# yellow_purple      8
# Name: composed_bf_ground, dtype: int64

# %% [markdown]
# ### How to deal with it:
# 1. yellow_purple, white_black -> reverse to black_white
# 2. white_purple, purple_purple -> change to white black. (the foreground seems darker in these cases)
# 3. Separate into two groups: 1. + 2.

# %%
back_ground_df = back_ground_df.set_index('ImageId')
back_ground_df.head(10)
# Out:
#                                                                                              filename  \
# ImageId
# d32ea6d318626ca14a967d0c1ad3218aebfe636624a8d11...  d32ea6d318626ca14a967d0c1ad3218aebfe636624a8d1...
# 4596961c789d3b41916492918797724fe75128239fefc51...  4596961c789d3b41916492918797724fe75128239fefc5...
# b6edad733399c83c8eb7a59c0d37b54e10cc0d59894e39f...  b6edad733399c83c8eb7a59c0d37b54e10cc0d59894e39...
# 831218e6a1a54b23d4be56c5799854e7eb978811b892153...  831218e6a1a54b23d4be56c5799854e7eb978811b89215...
# b1e3aeb0c56261c17eb71c747d116057b8da7e8c8a6845b...  b1e3aeb0c56261c17eb71c747d116057b8da7e8c8a6845...
# 4a424e0cb845cf6fd4d9fe62875552c7b89a4e0276cf16e...  4a424e0cb845cf6fd4d9fe62875552c7b89a4e0276cf16...
# 43cf6b2ec0b0745ac2b87b4d8780f62e9050d3f5d50a1fc...  43cf6b2ec0b0745ac2b87b4d8780f62e9050d3f5d50a1f...
# f487cc82271cf84b4414552aa8b0a9d82d902451ebe8e8b...  f487cc82271cf84b4414552aa8b0a9d82d902451ebe8e8...
# bf7691b0a79811fa068b7408cbce636a73f01ef9e971a95...  bf7691b0a79811fa068b7408cbce636a73f01ef9e971a9...
# df33b11184427e05c8a450f921586685975fe975f57315e...  df33b11184427e05c8a450f921586685975fe975f57315...
#
#                                                    foreground background  \
# ImageId
# d32ea6d318626ca14a967d0c1ad3218aebfe636624a8d11...      white      black
# 4596961c789d3b41916492918797724fe75128239fefc51...      white      black
# b6edad733399c83c8eb7a59c0d37b54e10cc0d59894e39f...      white      black
# 831218e6a1a54b23d4be56c5799854e7eb978811b892153...      white      black
# b1e3aeb0c56261c17eb71c747d116057b8da7e8c8a6845b...      white      black
# 4a424e0cb845cf6fd4d9fe62875552c7b89a4e0276cf16e...      white      black
# 43cf6b2ec0b0745ac2b87b4d8780f62e9050d3f5d50a1fc...      white      black
# f487cc82271cf84b4414552aa8b0a9d82d902451ebe8e8b...      white      black
# bf7691b0a79811fa068b7408cbce636a73f01ef9e971a95...      white      black
# df33b11184427e05c8a450f921586685975fe975f57315e...      white      black
#
#                                                    composed_bf_ground
# ImageId
# d32ea6d318626ca14a967d0c1ad3218aebfe636624a8d11...        black_white
# 4596961c789d3b41916492918797724fe75128239fefc51...        black_white
# b6edad733399c83c8eb7a59c0d37b54e10cc0d59894e39f...        black_white
# 831218e6a1a54b23d4be56c5799854e7eb978811b892153...        black_white
# b1e3aeb0c56261c17eb71c747d116057b8da7e8c8a6845b...        black_white
# 4a424e0cb845cf6fd4d9fe62875552c7b89a4e0276cf16e...        black_white
# 43cf6b2ec0b0745ac2b87b4d8780f62e9050d3f5d50a1fc...        black_white
# f487cc82271cf84b4414552aa8b0a9d82d902451ebe8e8b...        black_white
# bf7691b0a79811fa068b7408cbce636a73f01ef9e971a95...        black_white
# df33b11184427e05c8a450f921586685975fe975f57315e...        black_white

# %%
meta['bg_type'] = meta.ImageId.map(back_ground_df.composed_bf_ground)
meta['bg_type'].value_counts()
# Out:
# black_white      594
# purple_purple    100
# white_purple      41
# white_black       16
# yellow_purple      8
# Name: bg_type, dtype: int64

# %%
meta[meta['is_train']==1].bg_type.value_counts()
# Out:
# black_white      541
# purple_purple     99
# white_purple      38
# white_black       16
# Name: bg_type, dtype: int64

# %%
meta[meta['is_train']==0].bg_type.value_counts()
# Out:
# black_white      53
# yellow_purple     8
# white_purple      3
# purple_purple     1
# Name: bg_type, dtype: int64

# %%
meta['process_type'] = meta['bg_type'].map({
    'black_white': 2, # do nothing
    'white_black': 3, # pure reverse
    'purple_purple': 1, # turns into gray and reverse
    'yellow_purple': 1, # turns into gray and reverse
    'white_purple': 1 # turns into gray and reverse
})
meta['process_type'].value_counts()
# Out:
# 2    594
# 1    149
# 3     16
# Name: process_type, dtype: int64

# %%
meta['group'] = meta['bg_type'].map({
    'black_white': 0,
    'white_black': 0,
    'purple_purple': 0,
    'yellow_purple': 0,
    'white_purple': 0
})
meta['group'].value_counts()
# Out:
# 0    759
# Name: group, dtype: int64

# %%
def train_val_split(meta_train, val_size=0.1, random_state=719):
    meta_train_groups = [meta_train[meta_train['group'] == group].reset_index(drop=True) for group in range(1)]
    
    meta_train_val_groups = []
    
    for train_group in meta_train_groups:
        meta_train_val_groups
        val = train_group.sample(frac=val_size, random_state=random_state)
        tr = train_group[~train_group.index.isin(val.index)]
        
        meta_train_val_groups.append((tr, val))
    
    return meta_train_val_groups

def train_split(meta_train):
    meta_train_groups = [meta_train[meta_train['group'] == group].reset_index(drop=True) for group in range(2)]
    return meta_train_groups

# %%
IS_DEVELOP = False
if IS_DEVELOP:
    VAL_SIZE = .3
else:
    VAL_SIZE = 0.01

# %%
meta_train = meta[meta['is_train']==1]
meta_test = meta[meta['is_train']==0]
meta_train_val_groups = train_val_split(meta_train, val_size=VAL_SIZE, random_state=519)

for i in range(1):
    print(meta_train_val_groups[i][0].shape, meta_train_val_groups[i][1].shape)
# Out:
# (687, 7) (7, 7)

# %% [markdown]
# # Mask-RCNN configuration
# We will now define parameters for our mask-rcnn.
# Tweak them to get better results!

# %%
class DsbConfig(Config):

    # Give the configuration a recognizable name
    NAME = "dsb"
      
    LEARNING_RATE = 1e-2
    
    # If enabled, resizes instance masks to a smaller size to reduce
    # memory load. Recommended when using high-resolution image
    USE_MINI_MASK = True
    MINI_MASK_SHAPE = (56, 56)  # (height, width) of the mini-mask
    
    # Train on 1 GPU and 8 images per GPU. Batch size is GPUs * images/GPU.
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    # Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch.
    # typically be equal to the number of samples of your dataset divided by the batch size
    STEPS_PER_EPOCH = 300
    VALIDATION_STEPS = 70

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # background + nucleis
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    IMAGE_PADDING = True  # currently, the False option is not supported
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels, maybe add a 256?
    # The strides of each layer of the FPN Pyramid. These values
    # are based on a Resnet101 backbone.
    BACKBONE_STRIDES = [4, 8, 16, 32, 64]
    # How many anchors per image to use for RPN training
    RPN_TRAIN_ANCHORS_PER_IMAGE = 320 #300
    
    # ROIs kept after non-maximum supression (training and inference)
    POST_NMS_ROIS_TRAINING = 2000
    POST_NMS_ROIS_INFERENCE = 2000
    POOL_SIZE = 7
    MASK_POOL_SIZE = 14 # 14
    MASK_SHAPE = [28, 28] # 28
    TRAIN_ROIS_PER_IMAGE = 512
    RPN_DETECTION_MIN_CONFIDENCE = .6
    RPN_NMS_THRESHOLD = 0.6 #0.7
    MAX_GT_INSTANCES = 256
    DETECTION_MAX_INSTANCES = 450 
    # Minimum probability value to accept a detected instance
    # ROIs below this threshold are skipped
    DETECTION_MIN_CONFIDENCE = 0.67 # may be smaller?
    # Non-maximum suppression threshold for detection
    DETECTION_NMS_THRESHOLD = 0.3 # 0.3
    
    # DETECTION_MAX_INSTANCES=400, DETECTION_MIN_CONFIDENCE=.7 => Val loss: .21xx, LB: .424
    # DETECTION_MAX_INSTANCES=450, DETECTION_MIN_CONFIDENCE=.65 => Val loss: .3, LB: .438
    # DETECTION_MAX_INSTANCES=, DETECTION_MIN_CONFIDENCE= => Val loss: ., LB: .
    
    '''
    0324 note: 
        RPN_NMS_THRESHOLD .7 -> .6 to generate more proposals at training,
        DETECTION_MAX_INSTANCES 400 -> 450
        DETECTION_MIN_CONFIDENCE .7
        BACKBONE_STRIDES add `2` ..?
    '''
    
    MEAN_PIXEL = np.array([0.,0.,0.])
    
    # Weight decay regularization
    WEIGHT_DECAY = 0.0001
    
    # Min Box Size
    MIN_BOX_SIZE = 36./(512.**2.) # (36/512**2) (delete objects smaller than 6*6 pixels)
    BORDER_RATIO = 4. / 512. # smaller than 4 pixels width\height at the border
    BORDER_MIN_BOX_SIZE = 16./(512.**2.)
  
    LR_SHRINK_PERIOD = 10
    
config = DsbConfig()

# %% [markdown]
# # Agument functions

# %%
class Agg_Func():
    def __init__(self, funcs=[]):
        self.funcs = funcs
        
    def __call__(self, x):
        res = x
        for f in self.funcs:
            res = f(res)
        return res

# %%
class Augment():
    def __init__(self, rotate=True, flip=True):
        self.augment_funcs = []
        
        if flip:   
            self.augment_funcs.extend([
                Agg_Func(funcs=[]),
                Agg_Func(funcs=[np.fliplr]),
                Agg_Func(funcs=[np.flipud]),
                Agg_Func(funcs=[np.fliplr, np.flipud]),
            ])
            
            if rotate:
                self.augment_funcs.extend([
                    Agg_Func(funcs=[np.rot90]),
                    Agg_Func(funcs=[np.rot90, np.fliplr]),
                    Agg_Func(funcs=[np.rot90, np.flipud]),
                    Agg_Func(funcs=[np.rot90, np.fliplr, np.flipud]),
                ])
        elif rotate:
            self.augment_funcs.extend([
                Agg_Func(funcs=[]),
                Agg_Func(funcs=[np.rot90]),
            ])
    
    def get_random_augement(self):
        index = randrange(len(self.augment_funcs))
        return self.augment_funcs[index]
    
    def apply_all_augment(self, img):
        res = []
        for f in self.augment_funcs:
            res.append(f(img))
        return res

# %% [markdown]
# # Dataset definition
#
# We need to define our datasets for the data science bowl competition

# %%
class DsbDataset(utils.Dataset):

    '''
    process_info is a image-id <=> process type mapping pd.series
    '''
    def load_dataset(self, process_info, train_mode=True, augment=False):
        self.add_class("dsb", 1, "nuclei")
        self.process_info = process_info
        self.augmenter = Augment()
        self.augment = augment
        
        if train_mode:
            directory = dsb_dir
        else:
            directory = test_dir
            
        ids = []
        for i, id in enumerate(process_info.ImageId.values):
            image_dir = os.path.join(directory, id)
            self.add_image("dsb", image_id=i, path=image_dir)
            ids.append(i)
        
        self.process_info.reset_index(drop=True, inplace=True)
        #print(self.process_info)
        self.process_info['id'] = ids
        self.process_info.set_index('id')
        self.process_info = self.process_info['process_type']
        #print(self.process_info)
        
    def load_image(self, image_id, non_zero=None):
        info = self.image_info[image_id]
        path = info['path']
        image_name = os.listdir(os.path.join(path, 'images'))
        image_path = os.path.join(path, 'images', image_name[0])
        image = imageio.imread(image_path)
        
        #print(self.process_info[image_id])
        if image_path[-4:] == '.tif':
            self.offset = (randrange(488), randrange(488))
            image = image[self.offset[0]:self.offset[0]+512, self.offset[1]:self.offset[1]+512, :]
            #image = skimage.transform.resize(image, (512,512),  preserve_range=True)
        
        if image.shape[2] != 3:
            image = image[:,:,:3]

        image = self.preprocess(image, process_type=self.process_info[image_id])
        image = image.astype('float32')
        
        if self.augment:
            self.augment_func = self.augmenter.get_random_augement()
            image = self.augment_func(image)
            
        return image

    def image_reference(self, image_id):
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        path = info['path']
        mask_dir = os.path.join(path, 'masks')
        mask_names = os.listdir(mask_dir)
        count = len(mask_names)
        mask = []
        
        for i, el in enumerate(mask_names):
            msk_path = os.path.join(mask_dir, el)
            msk = imageio.imread(msk_path)
            if np.sum(msk) == 0:
                print('invalid mask')
                continue
                
            if 'TCGA' in mask_dir:
                #msk = skimage.transform.resize(msk, (512,512), preserve_range=True)
                msk = msk[self.offset[0]:self.offset[0]+512, self.offset[1]:self.offset[1]+512]
                if np.sum(msk) == 0:
                    continue
                
            msk = msk.astype('float32')/255.
            
            if len(msk.shape) > 2:
                msk = np.sum(msk, axis=2)
                
            mask.append(msk)
            
        try:
            mask = np.array(mask)
        except:
            for i, m in enumerate(mask):
                if len(m.shape) > 2:
                    print(mask_names[i])
                    
        mask[mask > 0.] = 1.
        mask = np.transpose(mask, (1,2,0))
        if self.augment:
            mask = self.augment_func(mask) # self.augment_func was decided when loading image before loading masks
            
        occlusion = np.logical_not(mask[:, :, -1]).astype(np.uint8)
        count = mask.shape[2]
        for i in range(count-2, -1, -1):
            mask[:, :, i] = mask[:, :, i] * occlusion
            occlusion = np.logical_and(occlusion, np.logical_not(mask[:, :, i]))
        class_ids = [self.class_names.index('nuclei') for s in range(count)]
        class_ids = np.asarray(class_ids)
        
        return mask, class_ids.astype(np.int32)
    
    def preprocess(self, img, process_type=0):
        
        if process_type == 0: # grey-rgb-grey
            gray = skimage.color.rgb2gray(img.astype('uint8'))
            img = skimage.color.gray2rgb(gray)
            img *= 255.
        elif process_type == 1:  # grey-rgb-grey-reverse
            gray = skimage.color.rgb2gray(img.astype('uint8'))
            img = skimage.color.gray2rgb(gray)
            img *= 255.
            img = 255. - img
        elif process_type == 2:
            img = img.astype(float)
            pass # do nothing
        elif process_type == 3:
            img = img.astype(float)
            img = 255. - img
        
        return img

# %%
dsb_dir = TRAIN_PATH
test_dir = TEST_PATH

# %%
'''
for i in range(2):
    print(meta_train_val_groups[i][0].shape, meta_train_val_groups[i][1].shape)
'''

datasets = []
for i in range(1):
    
    tr, val = meta_train_val_groups[i]

    # Training dataset
    dataset_train = DsbDataset()
    dataset_train.load_dataset(tr[['ImageId', 'process_type']], augment=True)
    dataset_train.prepare()

    # Validation dataset
    dataset_val = DsbDataset()
    dataset_val.load_dataset(val[['ImageId', 'process_type']])
    dataset_val.prepare()
    
    datasets.append((dataset_train, dataset_val))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Let's take a look at some images

# %%
for i in range(1):    
    dataset_train, _ = datasets[i]
    
    #image_ids = dataset_train.image_ids
    image_ids = np.random.choice(dataset_train.image_ids, 10)
    print('Loading group=',i)
    for image_id in image_ids:
        image = dataset_train.load_image(image_id)

        mask, class_ids = dataset_train.load_mask(image_id)
        
        print('image shape=', image.shape, 'mask shape=', mask.shape, 
              'bg type=', meta_train_val_groups[i][0].bg_type.values[image_id],
              'process type=', meta_train_val_groups[i][0].process_type.values[image_id])
        visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)
# Out:
# Loading group= 0
# image shape= (696, 520, 3) mask shape= (696, 520, 23) bg type= black_white process type= 2
# image shape= (360, 360, 3) mask shape= (360, 360, 26) bg type= black_white process type= 2
# image shape= (1024, 1024, 3) mask shape= (1024, 1024, 57) bg type= white_black process type= 3
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'decode_packbits'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'decode_lzw'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'unpack_ints'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'reverse_bitorder'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# image shape= (512, 512, 3) mask shape= (512, 512, 88) bg type= purple_purple process type= 1
# image shape= (256, 320, 3) mask shape= (256, 320, 51) bg type= white_purple process type= 1
# image shape= (256, 256, 3) mask shape= (256, 256, 8) bg type= black_white process type= 2
# image shape= (256, 320, 3) mask shape= (256, 320, 30) bg type= purple_purple process type= 1
# image shape= (256, 256, 3) mask shape= (256, 256, 56) bg type= black_white process type= 2
# image shape= (256, 256, 3) mask shape= (256, 256, 32) bg type= black_white process type= 2
# image shape= (256, 256, 3) mask shape= (256, 256, 53) bg type= black_white process type= 2

# %% [markdown]
# # Model Training
#
# OK!
#
# I think we are ready to do some training!
# We will instantiate the model and initialize it with COCO weights

# %%
if IS_DEVELOP:
    epochs = [10, 10]
    lr_shrink_period = [5, 5]
    inital_lr = 0.01
else:
    epochs = [100, 200]
    lr_shrink_period = [100, 150]
    inital_lr = 0.001
    
for i in range(1):
    train_index = i
    
    dataset_train, dataset_val = datasets[train_index]
    
    config.LEARNING_RATE = inital_lr
    config.LR_SHRINK_PERIOD = lr_shrink_period[train_index]
    config.STEPS_PER_EPOCH = len(dataset_train.image_ids) // config.IMAGES_PER_GPU
    
    model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
    
    init_with = "coco"  # imagenet, coco, or last

    if init_with == "imagenet":
        model.load_weights(model.get_imagenet_weights(), by_name=True)
    elif init_with == "coco":
        # Load weights trained on MS COCO, but skip layers that
        # are different due to the different number of classes
        # See README for instructions to download the COCO weights
        model.load_weights(COCO_MODEL_PATH, by_name=True,
                           exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                    "mrcnn_bbox", "mrcnn_mask"])
    elif init_with == "last":
        # Load the last model you trained and continue training
        model.load_weights(model.find_last()[1], by_name=True)
        
    model.train(dataset_train, dataset_val, 
                learning_rate=config.LEARNING_RATE,
                epochs=epochs[train_index], 
                layers="all", clbcks=[])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /data/khyeh/logs/dsb20180410T0123/mask_rcnn_dsb_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From Mask_RCNN/model.py:2157: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py:2087: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/100
# /usr/local/lib/python3.5/dist-packages/scipy/ndimage/interpolation.py:616: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# /usr/local/lib/python3.5/dist-packages/scipy/ndimage/interpolation.py:616: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# 116/343 [=========>....................] - ETA: 8:58 - loss: 1.8627 - rpn_class_loss: 0.2236 - rpn_bbox_loss: 0.8088 - mrcnn_class_loss: 0.0998 - mrcnn_bbox_loss: 0.4054 - mrcnn_mask_loss: 0.3252
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:7472: UserWarning: unexpected end of lzw stream (code 0)
#   warnings.warn("unexpected end of lzw stream (code %i)" % code)
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:3284: UserWarning: invalid tile data
#   warnings.warn("invalid tile data")
# 203/343 [================>.............] - ETA: 5:25 - loss: 1.6398 - rpn_class_loss: 0.1704 - rpn_bbox_loss: 0.7529 - mrcnn_class_loss: 0.0983 - mrcnn_bbox_loss: 0.3255 - mrcnn_mask_loss: 0.2927
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:7472: UserWarning: unexpected end of lzw stream (code 0)
#   warnings.warn("unexpected end of lzw stream (code %i)" % code)
# /usr/local/lib/python3.5/dist-packages/imageio/plugins/_tifffile.py:3284: UserWarning: invalid tile data
#   warnings.warn("invalid tile data")
# 343/343 [==============================] - 791s 2s/step - loss: 1.4513 - rpn_class_loss: 0.1284 - rpn_bbox_loss: 0.6621 - mrcnn_class_loss: 0.1110 - mrcnn_bbox_loss: 0.2758 - mrcnn_mask_loss: 0.2741 - val_loss: 0.8218 - val_rpn_class_loss: 0.0315 - val_rpn_bbox_loss: 0.3929 - val_mrcnn_class_loss: 0.1101 - val_mrcnn_bbox_loss: 0.1248 - val_mrcnn_mask_loss: 0.1626
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.9561 - rpn_class_loss: 0.0478 - rpn_bbox_loss: 0.3714 - mrcnn_class_loss: 0.1177 - mrcnn_bbox_loss: 0.1829 - mrcnn_mask_loss: 0.2363 - val_loss: 0.6356 - val_rpn_class_loss: 0.0157 - val_rpn_bbox_loss: 0.2721 - val_mrcnn_class_loss: 0.0913 - val_mrcnn_bbox_loss: 0.1031 - val_mrcnn_mask_loss: 0.1534
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 775s 2s/step - loss: 0.8707 - rpn_class_loss: 0.0413 - rpn_bbox_loss: 0.3128 - mrcnn_class_loss: 0.1131 - mrcnn_bbox_loss: 0.1702 - mrcnn_mask_loss: 0.2333 - val_loss: 0.5592 - val_rpn_class_loss: 0.0164 - val_rpn_bbox_loss: 0.2055 - val_mrcnn_class_loss: 0.0734 - val_mrcnn_bbox_loss: 0.1033 - val_mrcnn_mask_loss: 0.1607
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.8204 - rpn_class_loss: 0.0358 - rpn_bbox_loss: 0.2825 - mrcnn_class_loss: 0.1086 - mrcnn_bbox_loss: 0.1639 - mrcnn_mask_loss: 0.2297 - val_loss: 0.5049 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.1618 - val_mrcnn_class_loss: 0.0817 - val_mrcnn_bbox_loss: 0.0974 - val_mrcnn_mask_loss: 0.1536
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 775s 2s/step - loss: 0.8001 - rpn_class_loss: 0.0336 - rpn_bbox_loss: 0.2636 - mrcnn_class_loss: 0.1078 - mrcnn_bbox_loss: 0.1628 - mrcnn_mask_loss: 0.2324 - val_loss: 0.5012 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.1595 - val_mrcnn_class_loss: 0.0725 - val_mrcnn_bbox_loss: 0.1019 - val_mrcnn_mask_loss: 0.1581
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 775s 2s/step - loss: 0.7646 - rpn_class_loss: 0.0316 - rpn_bbox_loss: 0.2471 - mrcnn_class_loss: 0.1072 - mrcnn_bbox_loss: 0.1522 - mrcnn_mask_loss: 0.2265 - val_loss: 0.4387 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.1367 - val_mrcnn_class_loss: 0.0584 - val_mrcnn_bbox_loss: 0.0800 - val_mrcnn_mask_loss: 0.1549
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.7398 - rpn_class_loss: 0.0300 - rpn_bbox_loss: 0.2404 - mrcnn_class_loss: 0.0978 - mrcnn_bbox_loss: 0.1470 - mrcnn_mask_loss: 0.2247 - val_loss: 0.4524 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.1346 - val_mrcnn_class_loss: 0.0681 - val_mrcnn_bbox_loss: 0.0793 - val_mrcnn_mask_loss: 0.1602
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.7342 - rpn_class_loss: 0.0296 - rpn_bbox_loss: 0.2318 - mrcnn_class_loss: 0.1018 - mrcnn_bbox_loss: 0.1469 - mrcnn_mask_loss: 0.2241 - val_loss: 0.4424 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.1135 - val_mrcnn_class_loss: 0.0928 - val_mrcnn_bbox_loss: 0.0784 - val_mrcnn_mask_loss: 0.1503
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.7252 - rpn_class_loss: 0.0281 - rpn_bbox_loss: 0.2222 - mrcnn_class_loss: 0.1009 - mrcnn_bbox_loss: 0.1473 - mrcnn_mask_loss: 0.2266 - val_loss: 0.4566 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.1139 - val_mrcnn_class_loss: 0.0743 - val_mrcnn_bbox_loss: 0.0929 - val_mrcnn_mask_loss: 0.1673
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.6861 - rpn_class_loss: 0.0258 - rpn_bbox_loss: 0.2117 - mrcnn_class_loss: 0.0925 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2184 - val_loss: 0.4322 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.1032 - val_mrcnn_class_loss: 0.0646 - val_mrcnn_bbox_loss: 0.0936 - val_mrcnn_mask_loss: 0.1597
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.6935 - rpn_class_loss: 0.0261 - rpn_bbox_loss: 0.2099 - mrcnn_class_loss: 0.0954 - mrcnn_bbox_loss: 0.1397 - mrcnn_mask_loss: 0.2223 - val_loss: 0.4369 - val_rpn_class_loss: 0.0117 - val_rpn_bbox_loss: 0.1174 - val_mrcnn_class_loss: 0.0633 - val_mrcnn_bbox_loss: 0.0791 - val_mrcnn_mask_loss: 0.1654
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.6892 - rpn_class_loss: 0.0251 - rpn_bbox_loss: 0.2082 - mrcnn_class_loss: 0.0919 - mrcnn_bbox_loss: 0.1413 - mrcnn_mask_loss: 0.2227 - val_loss: 0.4120 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.1124 - val_mrcnn_class_loss: 0.0739 - val_mrcnn_bbox_loss: 0.0688 - val_mrcnn_mask_loss: 0.1483
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.6515 - rpn_class_loss: 0.0230 - rpn_bbox_loss: 0.1990 - mrcnn_class_loss: 0.0863 - mrcnn_bbox_loss: 0.1298 - mrcnn_mask_loss: 0.2133 - val_loss: 0.4153 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.1167 - val_mrcnn_class_loss: 0.0559 - val_mrcnn_bbox_loss: 0.0769 - val_mrcnn_mask_loss: 0.1554
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.7037 - rpn_class_loss: 0.0250 - rpn_bbox_loss: 0.2131 - mrcnn_class_loss: 0.0955 - mrcnn_bbox_loss: 0.1430 - mrcnn_mask_loss: 0.2271 - val_loss: 0.4104 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.1052 - val_mrcnn_class_loss: 0.0575 - val_mrcnn_bbox_loss: 0.0763 - val_mrcnn_mask_loss: 0.1615
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 777s 2s/step - loss: 0.6698 - rpn_class_loss: 0.0240 - rpn_bbox_loss: 0.2003 - mrcnn_class_loss: 0.0898 - mrcnn_bbox_loss: 0.1347 - mrcnn_mask_loss: 0.2211 - val_loss: 0.4043 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.1028 - val_mrcnn_class_loss: 0.0513 - val_mrcnn_bbox_loss: 0.0818 - val_mrcnn_mask_loss: 0.1574
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.6508 - rpn_class_loss: 0.0225 - rpn_bbox_loss: 0.1955 - mrcnn_class_loss: 0.0845 - mrcnn_bbox_loss: 0.1315 - mrcnn_mask_loss: 0.2169 - val_loss: 0.4460 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.1298 - val_mrcnn_class_loss: 0.0565 - val_mrcnn_bbox_loss: 0.0918 - val_mrcnn_mask_loss: 0.1588
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.6559 - rpn_class_loss: 0.0223 - rpn_bbox_loss: 0.1955 - mrcnn_class_loss: 0.0858 - mrcnn_bbox_loss: 0.1328 - mrcnn_mask_loss: 0.2195 - val_loss: 0.4532 - val_rpn_class_loss: 0.0183 - val_rpn_bbox_loss: 0.1268 - val_mrcnn_class_loss: 0.0654 - val_mrcnn_bbox_loss: 0.0803 - val_mrcnn_mask_loss: 0.1624
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 777s 2s/step - loss: 0.6496 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.1920 - mrcnn_class_loss: 0.0875 - mrcnn_bbox_loss: 0.1298 - mrcnn_mask_loss: 0.2175 - val_loss: 0.4230 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.1152 - val_mrcnn_class_loss: 0.0461 - val_mrcnn_bbox_loss: 0.0878 - val_mrcnn_mask_loss: 0.1624
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 775s 2s/step - loss: 0.6352 - rpn_class_loss: 0.0220 - rpn_bbox_loss: 0.1839 - mrcnn_class_loss: 0.0835 - mrcnn_bbox_loss: 0.1281 - mrcnn_mask_loss: 0.2177 - val_loss: 0.4005 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.0907 - val_mrcnn_class_loss: 0.0628 - val_mrcnn_bbox_loss: 0.0749 - val_mrcnn_mask_loss: 0.1606
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.6202 - rpn_class_loss: 0.0206 - rpn_bbox_loss: 0.1824 - mrcnn_class_loss: 0.0840 - mrcnn_bbox_loss: 0.1226 - mrcnn_mask_loss: 0.2106 - val_loss: 0.4345 - val_rpn_class_loss: 0.0132 - val_rpn_bbox_loss: 0.1136 - val_mrcnn_class_loss: 0.0567 - val_mrcnn_bbox_loss: 0.0856 - val_mrcnn_mask_loss: 0.1653
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.6414 - rpn_class_loss: 0.0221 - rpn_bbox_loss: 0.1869 - mrcnn_class_loss: 0.0862 - mrcnn_bbox_loss: 0.1286 - mrcnn_mask_loss: 0.2176 - val_loss: 0.4211 - val_rpn_class_loss: 0.0141 - val_rpn_bbox_loss: 0.1012 - val_mrcnn_class_loss: 0.0636 - val_mrcnn_bbox_loss: 0.0812 - val_mrcnn_mask_loss: 0.1609
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 781s 2s/step - loss: 0.6308 - rpn_class_loss: 0.0214 - rpn_bbox_loss: 0.1856 - mrcnn_class_loss: 0.0830 - mrcnn_bbox_loss: 0.1262 - mrcnn_mask_loss: 0.2147 - val_loss: 0.3280 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.0704 - val_mrcnn_class_loss: 0.0537 - val_mrcnn_bbox_loss: 0.0556 - val_mrcnn_mask_loss: 0.1422
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.6151 - rpn_class_loss: 0.0192 - rpn_bbox_loss: 0.1768 - mrcnn_class_loss: 0.0812 - mrcnn_bbox_loss: 0.1241 - mrcnn_mask_loss: 0.2137 - val_loss: 0.3848 - val_rpn_class_loss: 0.0171 - val_rpn_bbox_loss: 0.1009 - val_mrcnn_class_loss: 0.0530 - val_mrcnn_bbox_loss: 0.0634 - val_mrcnn_mask_loss: 0.1504
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 782s 2s/step - loss: 0.6292 - rpn_class_loss: 0.0211 - rpn_bbox_loss: 0.1829 - mrcnn_class_loss: 0.0831 - mrcnn_bbox_loss: 0.1264 - mrcnn_mask_loss: 0.2158 - val_loss: 0.3776 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.0850 - val_mrcnn_class_loss: 0.0636 - val_mrcnn_bbox_loss: 0.0653 - val_mrcnn_mask_loss: 0.1526
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.6070 - rpn_class_loss: 0.0199 - rpn_bbox_loss: 0.1729 - mrcnn_class_loss: 0.0780 - mrcnn_bbox_loss: 0.1230 - mrcnn_mask_loss: 0.2132 - val_loss: 0.4192 - val_rpn_class_loss: 0.0152 - val_rpn_bbox_loss: 0.1020 - val_mrcnn_class_loss: 0.0606 - val_mrcnn_bbox_loss: 0.0822 - val_mrcnn_mask_loss: 0.1592
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 777s 2s/step - loss: 0.6392 - rpn_class_loss: 0.0202 - rpn_bbox_loss: 0.1841 - mrcnn_class_loss: 0.0820 - mrcnn_bbox_loss: 0.1301 - mrcnn_mask_loss: 0.2227 - val_loss: 0.4152 - val_rpn_class_loss: 0.0120 - val_rpn_bbox_loss: 0.1029 - val_mrcnn_class_loss: 0.0608 - val_mrcnn_bbox_loss: 0.0772 - val_mrcnn_mask_loss: 0.1623
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.6036 - rpn_class_loss: 0.0200 - rpn_bbox_loss: 0.1712 - mrcnn_class_loss: 0.0791 - mrcnn_bbox_loss: 0.1206 - mrcnn_mask_loss: 0.2127 - val_loss: 0.3535 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.0849 - val_mrcnn_class_loss: 0.0432 - val_mrcnn_bbox_loss: 0.0671 - val_mrcnn_mask_loss: 0.1490
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.6146 - rpn_class_loss: 0.0185 - rpn_bbox_loss: 0.1738 - mrcnn_class_loss: 0.0810 - mrcnn_bbox_loss: 0.1245 - mrcnn_mask_loss: 0.2168 - val_loss: 0.3965 - val_rpn_class_loss: 0.0167 - val_rpn_bbox_loss: 0.1133 - val_mrcnn_class_loss: 0.0383 - val_mrcnn_bbox_loss: 0.0704 - val_mrcnn_mask_loss: 0.1579
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.6036 - rpn_class_loss: 0.0187 - rpn_bbox_loss: 0.1753 - mrcnn_class_loss: 0.0734 - mrcnn_bbox_loss: 0.1221 - mrcnn_mask_loss: 0.2141 - val_loss: 0.3876 - val_rpn_class_loss: 0.0139 - val_rpn_bbox_loss: 0.1064 - val_mrcnn_class_loss: 0.0457 - val_mrcnn_bbox_loss: 0.0666 - val_mrcnn_mask_loss: 0.1550
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.6063 - rpn_class_loss: 0.0200 - rpn_bbox_loss: 0.1674 - mrcnn_class_loss: 0.0836 - mrcnn_bbox_loss: 0.1215 - mrcnn_mask_loss: 0.2138 - val_loss: 0.3849 - val_rpn_class_loss: 0.0134 - val_rpn_bbox_loss: 0.1009 - val_mrcnn_class_loss: 0.0408 - val_mrcnn_bbox_loss: 0.0679 - val_mrcnn_mask_loss: 0.1618
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 775s 2s/step - loss: 0.5875 - rpn_class_loss: 0.0181 - rpn_bbox_loss: 0.1672 - mrcnn_class_loss: 0.0743 - mrcnn_bbox_loss: 0.1177 - mrcnn_mask_loss: 0.2101 - val_loss: 0.3808 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.1050 - val_mrcnn_class_loss: 0.0439 - val_mrcnn_bbox_loss: 0.0701 - val_mrcnn_mask_loss: 0.1507
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.6040 - rpn_class_loss: 0.0190 - rpn_bbox_loss: 0.1680 - mrcnn_class_loss: 0.0777 - mrcnn_bbox_loss: 0.1222 - mrcnn_mask_loss: 0.2170 - val_loss: 0.3730 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.0943 - val_mrcnn_class_loss: 0.0324 - val_mrcnn_bbox_loss: 0.0679 - val_mrcnn_mask_loss: 0.1678
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 783s 2s/step - loss: 0.6069 - rpn_class_loss: 0.0183 - rpn_bbox_loss: 0.1689 - mrcnn_class_loss: 0.0784 - mrcnn_bbox_loss: 0.1225 - mrcnn_mask_loss: 0.2188 - val_loss: 0.4354 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.1164 - val_mrcnn_class_loss: 0.0393 - val_mrcnn_bbox_loss: 0.0808 - val_mrcnn_mask_loss: 0.1874
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 783s 2s/step - loss: 0.6045 - rpn_class_loss: 0.0179 - rpn_bbox_loss: 0.1722 - mrcnn_class_loss: 0.0736 - mrcnn_bbox_loss: 0.1245 - mrcnn_mask_loss: 0.2164 - val_loss: 0.3521 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.0911 - val_mrcnn_class_loss: 0.0247 - val_mrcnn_bbox_loss: 0.0682 - val_mrcnn_mask_loss: 0.1578
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 784s 2s/step - loss: 0.6095 - rpn_class_loss: 0.0191 - rpn_bbox_loss: 0.1704 - mrcnn_class_loss: 0.0760 - mrcnn_bbox_loss: 0.1242 - mrcnn_mask_loss: 0.2198 - val_loss: 0.3987 - val_rpn_class_loss: 0.0124 - val_rpn_bbox_loss: 0.1018 - val_mrcnn_class_loss: 0.0410 - val_mrcnn_bbox_loss: 0.0796 - val_mrcnn_mask_loss: 0.1638
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5688 - rpn_class_loss: 0.0176 - rpn_bbox_loss: 0.1539 - mrcnn_class_loss: 0.0703 - mrcnn_bbox_loss: 0.1156 - mrcnn_mask_loss: 0.2115 - val_loss: 0.4442 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.1143 - val_mrcnn_class_loss: 0.0260 - val_mrcnn_bbox_loss: 0.1035 - val_mrcnn_mask_loss: 0.1855
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.5753 - rpn_class_loss: 0.0177 - rpn_bbox_loss: 0.1605 - mrcnn_class_loss: 0.0690 - mrcnn_bbox_loss: 0.1155 - mrcnn_mask_loss: 0.2127 - val_loss: 0.4130 - val_rpn_class_loss: 0.0208 - val_rpn_bbox_loss: 0.1240 - val_mrcnn_class_loss: 0.0327 - val_mrcnn_bbox_loss: 0.0672 - val_mrcnn_mask_loss: 0.1683
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 777s 2s/step - loss: 0.5835 - rpn_class_loss: 0.0176 - rpn_bbox_loss: 0.1582 - mrcnn_class_loss: 0.0731 - mrcnn_bbox_loss: 0.1196 - mrcnn_mask_loss: 0.2150 - val_loss: 0.4133 - val_rpn_class_loss: 0.0191 - val_rpn_bbox_loss: 0.1275 - val_mrcnn_class_loss: 0.0256 - val_mrcnn_bbox_loss: 0.0670 - val_mrcnn_mask_loss: 0.1741
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5778 - rpn_class_loss: 0.0166 - rpn_bbox_loss: 0.1584 - mrcnn_class_loss: 0.0701 - mrcnn_bbox_loss: 0.1167 - mrcnn_mask_loss: 0.2160 - val_loss: 0.4477 - val_rpn_class_loss: 0.0187 - val_rpn_bbox_loss: 0.1569 - val_mrcnn_class_loss: 0.0412 - val_mrcnn_bbox_loss: 0.0639 - val_mrcnn_mask_loss: 0.1670
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.5750 - rpn_class_loss: 0.0175 - rpn_bbox_loss: 0.1570 - mrcnn_class_loss: 0.0702 - mrcnn_bbox_loss: 0.1165 - mrcnn_mask_loss: 0.2137 - val_loss: 0.4361 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.0965 - val_mrcnn_class_loss: 0.0669 - val_mrcnn_bbox_loss: 0.0952 - val_mrcnn_mask_loss: 0.1683
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5776 - rpn_class_loss: 0.0168 - rpn_bbox_loss: 0.1601 - mrcnn_class_loss: 0.0692 - mrcnn_bbox_loss: 0.1160 - mrcnn_mask_loss: 0.2154 - val_loss: 0.3917 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.0856 - val_mrcnn_class_loss: 0.0459 - val_mrcnn_bbox_loss: 0.0811 - val_mrcnn_mask_loss: 0.1699
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.5784 - rpn_class_loss: 0.0178 - rpn_bbox_loss: 0.1540 - mrcnn_class_loss: 0.0732 - mrcnn_bbox_loss: 0.1186 - mrcnn_mask_loss: 0.2148 - val_loss: 0.4315 - val_rpn_class_loss: 0.0171 - val_rpn_bbox_loss: 0.1401 - val_mrcnn_class_loss: 0.0180 - val_mrcnn_bbox_loss: 0.0891 - val_mrcnn_mask_loss: 0.1673
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.5480 - rpn_class_loss: 0.0164 - rpn_bbox_loss: 0.1473 - mrcnn_class_loss: 0.0675 - mrcnn_bbox_loss: 0.1094 - mrcnn_mask_loss: 0.2074 - val_loss: 0.4437 - val_rpn_class_loss: 0.0122 - val_rpn_bbox_loss: 0.1168 - val_mrcnn_class_loss: 0.0327 - val_mrcnn_bbox_loss: 0.1004 - val_mrcnn_mask_loss: 0.1816
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5791 - rpn_class_loss: 0.0175 - rpn_bbox_loss: 0.1578 - mrcnn_class_loss: 0.0703 - mrcnn_bbox_loss: 0.1169 - mrcnn_mask_loss: 0.2166 - val_loss: 0.4632 - val_rpn_class_loss: 0.0125 - val_rpn_bbox_loss: 0.1141 - val_mrcnn_class_loss: 0.0460 - val_mrcnn_bbox_loss: 0.1081 - val_mrcnn_mask_loss: 0.1826
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 777s 2s/step - loss: 0.5677 - rpn_class_loss: 0.0175 - rpn_bbox_loss: 0.1531 - mrcnn_class_loss: 0.0692 - mrcnn_bbox_loss: 0.1144 - mrcnn_mask_loss: 0.2134 - val_loss: 0.4932 - val_rpn_class_loss: 0.0219 - val_rpn_bbox_loss: 0.1612 - val_mrcnn_class_loss: 0.0336 - val_mrcnn_bbox_loss: 0.0970 - val_mrcnn_mask_loss: 0.1795
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5484 - rpn_class_loss: 0.0150 - rpn_bbox_loss: 0.1480 - mrcnn_class_loss: 0.0627 - mrcnn_bbox_loss: 0.1116 - mrcnn_mask_loss: 0.2112 - val_loss: 0.4766 - val_rpn_class_loss: 0.0213 - val_rpn_bbox_loss: 0.1587 - val_mrcnn_class_loss: 0.0422 - val_mrcnn_bbox_loss: 0.0837 - val_mrcnn_mask_loss: 0.1707
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 782s 2s/step - loss: 0.5889 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.1600 - mrcnn_class_loss: 0.0697 - mrcnn_bbox_loss: 0.1197 - mrcnn_mask_loss: 0.2223 - val_loss: 0.4318 - val_rpn_class_loss: 0.0200 - val_rpn_bbox_loss: 0.1327 - val_mrcnn_class_loss: 0.0231 - val_mrcnn_bbox_loss: 0.0761 - val_mrcnn_mask_loss: 0.1799
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 782s 2s/step - loss: 0.5211 - rpn_class_loss: 0.0141 - rpn_bbox_loss: 0.1355 - mrcnn_class_loss: 0.0633 - mrcnn_bbox_loss: 0.1042 - mrcnn_mask_loss: 0.2039 - val_loss: 0.4437 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.1450 - val_mrcnn_class_loss: 0.0339 - val_mrcnn_bbox_loss: 0.0787 - val_mrcnn_mask_loss: 0.1679
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 782s 2s/step - loss: 0.5609 - rpn_class_loss: 0.0160 - rpn_bbox_loss: 0.1516 - mrcnn_class_loss: 0.0654 - mrcnn_bbox_loss: 0.1128 - mrcnn_mask_loss: 0.2149 - val_loss: 0.4490 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.1274 - val_mrcnn_class_loss: 0.0243 - val_mrcnn_bbox_loss: 0.1003 - val_mrcnn_mask_loss: 0.1834
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.5427 - rpn_class_loss: 0.0166 - rpn_bbox_loss: 0.1419 - mrcnn_class_loss: 0.0655 - mrcnn_bbox_loss: 0.1090 - mrcnn_mask_loss: 0.2097 - val_loss: 0.4948 - val_rpn_class_loss: 0.0190 - val_rpn_bbox_loss: 0.1491 - val_mrcnn_class_loss: 0.0327 - val_mrcnn_bbox_loss: 0.0965 - val_mrcnn_mask_loss: 0.1975
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.5511 - rpn_class_loss: 0.0158 - rpn_bbox_loss: 0.1492 - mrcnn_class_loss: 0.0627 - mrcnn_bbox_loss: 0.1117 - mrcnn_mask_loss: 0.2117 - val_loss: 0.4303 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.1185 - val_mrcnn_class_loss: 0.0413 - val_mrcnn_bbox_loss: 0.0874 - val_mrcnn_mask_loss: 0.1702
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.5521 - rpn_class_loss: 0.0151 - rpn_bbox_loss: 0.1432 - mrcnn_class_loss: 0.0655 - mrcnn_bbox_loss: 0.1123 - mrcnn_mask_loss: 0.2160 - val_loss: 0.4230 - val_rpn_class_loss: 0.0168 - val_rpn_bbox_loss: 0.1178 - val_mrcnn_class_loss: 0.0269 - val_mrcnn_bbox_loss: 0.0869 - val_mrcnn_mask_loss: 0.1746
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 782s 2s/step - loss: 0.5410 - rpn_class_loss: 0.0145 - rpn_bbox_loss: 0.1427 - mrcnn_class_loss: 0.0623 - mrcnn_bbox_loss: 0.1097 - mrcnn_mask_loss: 0.2119 - val_loss: 0.3975 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.1086 - val_mrcnn_class_loss: 0.0303 - val_mrcnn_bbox_loss: 0.0712 - val_mrcnn_mask_loss: 0.1747
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 781s 2s/step - loss: 0.5508 - rpn_class_loss: 0.0153 - rpn_bbox_loss: 0.1475 - mrcnn_class_loss: 0.0632 - mrcnn_bbox_loss: 0.1111 - mrcnn_mask_loss: 0.2137 - val_loss: 0.5774 - val_rpn_class_loss: 0.0218 - val_rpn_bbox_loss: 0.1749 - val_mrcnn_class_loss: 0.0407 - val_mrcnn_bbox_loss: 0.1258 - val_mrcnn_mask_loss: 0.2142
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 782s 2s/step - loss: 0.5477 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.1450 - mrcnn_class_loss: 0.0649 - mrcnn_bbox_loss: 0.1093 - mrcnn_mask_loss: 0.2126 - val_loss: 0.4624 - val_rpn_class_loss: 0.0225 - val_rpn_bbox_loss: 0.1524 - val_mrcnn_class_loss: 0.0203 - val_mrcnn_bbox_loss: 0.0820 - val_mrcnn_mask_loss: 0.1852
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 784s 2s/step - loss: 0.5433 - rpn_class_loss: 0.0152 - rpn_bbox_loss: 0.1406 - mrcnn_class_loss: 0.0627 - mrcnn_bbox_loss: 0.1106 - mrcnn_mask_loss: 0.2142 - val_loss: 0.4958 - val_rpn_class_loss: 0.0166 - val_rpn_bbox_loss: 0.1424 - val_mrcnn_class_loss: 0.0188 - val_mrcnn_bbox_loss: 0.1050 - val_mrcnn_mask_loss: 0.2130
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 781s 2s/step - loss: 0.5497 - rpn_class_loss: 0.0150 - rpn_bbox_loss: 0.1459 - mrcnn_class_loss: 0.0634 - mrcnn_bbox_loss: 0.1114 - mrcnn_mask_loss: 0.2139 - val_loss: 0.4580 - val_rpn_class_loss: 0.0222 - val_rpn_bbox_loss: 0.1490 - val_mrcnn_class_loss: 0.0320 - val_mrcnn_bbox_loss: 0.0744 - val_mrcnn_mask_loss: 0.1803
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.5419 - rpn_class_loss: 0.0153 - rpn_bbox_loss: 0.1450 - mrcnn_class_loss: 0.0586 - mrcnn_bbox_loss: 0.1097 - mrcnn_mask_loss: 0.2133 - val_loss: 0.4784 - val_rpn_class_loss: 0.0185 - val_rpn_bbox_loss: 0.1374 - val_mrcnn_class_loss: 0.0292 - val_mrcnn_bbox_loss: 0.1071 - val_mrcnn_mask_loss: 0.1863
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.5226 - rpn_class_loss: 0.0138 - rpn_bbox_loss: 0.1352 - mrcnn_class_loss: 0.0605 - mrcnn_bbox_loss: 0.1045 - mrcnn_mask_loss: 0.2085 - val_loss: 0.5349 - val_rpn_class_loss: 0.0157 - val_rpn_bbox_loss: 0.1434 - val_mrcnn_class_loss: 0.0526 - val_mrcnn_bbox_loss: 0.1253 - val_mrcnn_mask_loss: 0.1979
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.5423 - rpn_class_loss: 0.0154 - rpn_bbox_loss: 0.1394 - mrcnn_class_loss: 0.0619 - mrcnn_bbox_loss: 0.1105 - mrcnn_mask_loss: 0.2152 - val_loss: 0.4784 - val_rpn_class_loss: 0.0211 - val_rpn_bbox_loss: 0.1649 - val_mrcnn_class_loss: 0.0218 - val_mrcnn_bbox_loss: 0.0795 - val_mrcnn_mask_loss: 0.1910
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 779s 2s/step - loss: 0.5166 - rpn_class_loss: 0.0137 - rpn_bbox_loss: 0.1324 - mrcnn_class_loss: 0.0584 - mrcnn_bbox_loss: 0.1037 - mrcnn_mask_loss: 0.2084 - val_loss: 0.4575 - val_rpn_class_loss: 0.0179 - val_rpn_bbox_loss: 0.1377 - val_mrcnn_class_loss: 0.0341 - val_mrcnn_bbox_loss: 0.0802 - val_mrcnn_mask_loss: 0.1876
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 780s 2s/step - loss: 0.5199 - rpn_class_loss: 0.0150 - rpn_bbox_loss: 0.1342 - mrcnn_class_loss: 0.0577 - mrcnn_bbox_loss: 0.1028 - mrcnn_mask_loss: 0.2102 - val_loss: 0.5259 - val_rpn_class_loss: 0.0237 - val_rpn_bbox_loss: 0.1832 - val_mrcnn_class_loss: 0.0375 - val_mrcnn_bbox_loss: 0.0935 - val_mrcnn_mask_loss: 0.1880
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5282 - rpn_class_loss: 0.0152 - rpn_bbox_loss: 0.1352 - mrcnn_class_loss: 0.0633 - mrcnn_bbox_loss: 0.1053 - mrcnn_mask_loss: 0.2093 - val_loss: 0.4254 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.1120 - val_mrcnn_class_loss: 0.0180 - val_mrcnn_bbox_loss: 0.0921 - val_mrcnn_mask_loss: 0.1917
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.5348 - rpn_class_loss: 0.0145 - rpn_bbox_loss: 0.1389 - mrcnn_class_loss: 0.0577 - mrcnn_bbox_loss: 0.1078 - mrcnn_mask_loss: 0.2159 - val_loss: 0.4451 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.1253 - val_mrcnn_class_loss: 0.0285 - val_mrcnn_bbox_loss: 0.0960 - val_mrcnn_mask_loss: 0.1803
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5205 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.1351 - mrcnn_class_loss: 0.0568 - mrcnn_bbox_loss: 0.1052 - mrcnn_mask_loss: 0.2100 - val_loss: 0.4124 - val_rpn_class_loss: 0.0142 - val_rpn_bbox_loss: 0.1241 - val_mrcnn_class_loss: 0.0223 - val_mrcnn_bbox_loss: 0.0698 - val_mrcnn_mask_loss: 0.1821
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.5274 - rpn_class_loss: 0.0146 - rpn_bbox_loss: 0.1341 - mrcnn_class_loss: 0.0602 - mrcnn_bbox_loss: 0.1058 - mrcnn_mask_loss: 0.2127 - val_loss: 0.4471 - val_rpn_class_loss: 0.0168 - val_rpn_bbox_loss: 0.1176 - val_mrcnn_class_loss: 0.0302 - val_mrcnn_bbox_loss: 0.0917 - val_mrcnn_mask_loss: 0.1908
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 775s 2s/step - loss: 0.5382 - rpn_class_loss: 0.0150 - rpn_bbox_loss: 0.1370 - mrcnn_class_loss: 0.0614 - mrcnn_bbox_loss: 0.1085 - mrcnn_mask_loss: 0.2164 - val_loss: 0.4850 - val_rpn_class_loss: 0.0222 - val_rpn_bbox_loss: 0.1662 - val_mrcnn_class_loss: 0.0181 - val_mrcnn_bbox_loss: 0.0847 - val_mrcnn_mask_loss: 0.1939
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.5053 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.1315 - mrcnn_class_loss: 0.0552 - mrcnn_bbox_loss: 0.1002 - mrcnn_mask_loss: 0.2051 - val_loss: 0.5038 - val_rpn_class_loss: 0.0214 - val_rpn_bbox_loss: 0.1623 - val_mrcnn_class_loss: 0.0403 - val_mrcnn_bbox_loss: 0.0918 - val_mrcnn_mask_loss: 0.1880
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 776s 2s/step - loss: 0.5187 - rpn_class_loss: 0.0143 - rpn_bbox_loss: 0.1338 - mrcnn_class_loss: 0.0571 - mrcnn_bbox_loss: 0.1036 - mrcnn_mask_loss: 0.2099 - val_loss: 0.5269 - val_rpn_class_loss: 0.0230 - val_rpn_bbox_loss: 0.1760 - val_mrcnn_class_loss: 0.0246 - val_mrcnn_bbox_loss: 0.1066 - val_mrcnn_mask_loss: 0.1967
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 778s 2s/step - loss: 0.5103 - rpn_class_loss: 0.0128 - rpn_bbox_loss: 0.1292 - mrcnn_class_loss: 0.0559 - mrcnn_bbox_loss: 0.1015 - mrcnn_mask_loss: 0.2109 - val_loss: 0.4514 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.1455 - val_mrcnn_class_loss: 0.0258 - val_mrcnn_bbox_loss: 0.0777 - val_mrcnn_mask_loss: 0.1896
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.001.
# 343/343 [==============================] - 777s 2s/step - loss: 0.5147 - rpn_class_loss: 0.0137 - rpn_bbox_loss: 0.1304 - mrcnn_class_loss: 0.0563 - mrcnn_bbox_loss: 0.1028 - mrcnn_mask_loss: 0.2115 - val_loss: 0.4798 - val_rpn_class_loss: 0.0136 - val_rpn_bbox_loss: 0.1297 - val_mrcnn_class_loss: 0.0354 - val_mrcnn_bbox_loss: 0.0992 - val_mrcnn_mask_loss: 0.2019
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.001.
# 304/343 [=========================>....] - ETA: 1:28 - loss: 0.5155 - rpn_class_loss: 0.0131 - rpn_bbox_loss: 0.1328 - mrcnn_class_loss: 0.0562 - mrcnn_bbox_loss: 0.1030 - mrcnn_mask_loss: 0.2104
# Process Process-3:
# Process Process-2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/keras/utils/data_utils.py", line 680, in _data_generator_task
#     time.sleep(self.wait_time)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/keras/utils/data_utils.py", line 678, in _data_generator_task
#     self.queue.put((True, generator_output))
#   File "<string>", line 2, in put
#   File "/usr/lib/python3.5/multiprocessing/managers.py", line 717, in _callmethod
#     kind, result = conn.recv()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-29-c954d2a8f872> in <module>()
#      38                 learning_rate=config.LEARNING_RATE,
#      39                 epochs=epochs[train_index],
# ---> 40                 layers="all", clbcks=[])
#
# /data/khyeh/Mask_RCNN/model.py in train(self, train_dataset, val_dataset, learning_rate, epochs, layers, clbcks)
#    2323             max_queue_size=100,
#    2324             workers=workers,
# -> 2325             use_multiprocessing=True,
#    2326         )
#    2327         self.epoch = max(self.epoch, epochs)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2222                     outs = self.train_on_batch(x, y,
#    2223                                                sample_weight=sample_weight,
# -> 2224                                                class_weight=class_weight)
#    2225
#    2226                     if not isinstance(outs, list):
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1881             ins = x + y + sample_weights
#    1882         self._make_train_function()
# -> 1883         outputs = self.train_function(ins)
#    1884         if len(outputs) == 1:
#    1885             return outputs[0]
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Let's train and investigate the learning curves for all the mask-rcnn losses in the `charts` and `channels`
